# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./data/서울교통공사_1_8호선 역별 일별 승객유형별 수송인원(환승유입인원 포함) 정보_20231231.CSV', encoding='euc-kr')
data.head()
# Out:
#    연번          날짜   호선  역번호   역명 승객유형   승차인원  환승유입인원
# 0   1  2023-01-01  1호선  150  서울역   일반  27121   14887
# 1   2  2023-01-01  1호선  150  서울역  어린이    331     161
# 2   3  2023-01-01  1호선  150  서울역  중고생     10       7
# 3   4  2023-01-01  1호선  150  서울역  청소년    611     384
# 4   5  2023-01-01  1호선  150  서울역  우대권   3454    1867

# %% [markdown]
# ---
# 어린이대공원역만 분리 후 저장

# %%
data['역명'].unique()
# Out:
# array(['서울역', '시청', '종각', '종로3가', '종로5가', '동대문', '신설동', '제기동',
#        '청량리(서울시립대입구)', '동묘앞', '을지로입구', '을지로3가', '을지로4가', '동대문역사문화공원(DDP)',
#        '신당', '상왕십리', '왕십리(성동구청)', '한양대', '뚝섬', '성수', '건대입구', '구의(광진구청)',
#        '강변(동서울터미널)', '잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '삼성(무역센터)',
#        '선릉', '역삼', '강남', '교대(법원.검찰청)', '서초', '방배', '사당', '낙성대(강감찬)',
#        '서울대입구(관악구청)', '봉천', '신림', '신대방', '구로디지털단지', '대림(구로구청)', '신도림',
#        '문래', '영등포구청', '당산', '합정', '홍대입구', '신촌', '이대', '아현', '충정로(경기대입구)',
#        '용답', '신답', '도림천', '양천구청', '신정네거리', '용두(동대문구청)', '지축', '구파발',
#        '연신내', '불광', '녹번', '홍제', '무악재', '독립문', '경복궁(정부서울청사)', '안국', '동대입구',
#        '약수', '금호', '옥수', '압구정', '신사', '잠원', '고속터미널', '남부터미널(예술의전당)',
#        '양재(서초구청)', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '가락시장',
#        '경찰병원', '오금', '당고개', '상계', '노원', '창동', '쌍문', '수유(강북구청)',
#        '미아(서울사이버대학)', '미아사거리', '길음', '성신여대입구(돈암)', '한성대입구(삼선교)', '혜화',
# ...

# %%
data = data[data['역명']=='어린이대공원(세종대)']
data.head()
# Out:
#         연번          날짜   호선   역번호           역명 승객유형  승차인원  환승유입인원
# 1862  1863  2023-01-01  7호선  2728  어린이대공원(세종대)   일반  4627    3003
# 1863  1864  2023-01-01  7호선  2728  어린이대공원(세종대)  어린이    63      36
# 1864  1865  2023-01-01  7호선  2728  어린이대공원(세종대)  중고생     1       1
# 1865  1866  2023-01-01  7호선  2728  어린이대공원(세종대)  청소년   182      92
# 1866  1867  2023-01-01  7호선  2728  어린이대공원(세종대)  우대권   678     323

# %%
data.drop(
    ['연번', '호선', '역번호', '역명'],
    axis=1,
    inplace=True
)

# %%
data.to_csv('./data/어린이대공원2023.csv',index=False)

# %% [markdown]
# ---
# 다른 역들에 비해 어린이 비율이 높은지 확인하기

# %%
alldata = pd.read_csv('./data/서울교통공사_1_8호선 역별 일별 승객유형별 수송인원(환승유입인원 포함) 정보_20231231.CSV', encoding='euc-kr')
alldata.head()
# Out:
#    연번          날짜   호선  역번호   역명 승객유형   승차인원  환승유입인원
# 0   1  2023-01-01  1호선  150  서울역   일반  27121   14887
# 1   2  2023-01-01  1호선  150  서울역  어린이    331     161
# 2   3  2023-01-01  1호선  150  서울역  중고생     10       7
# 3   4  2023-01-01  1호선  150  서울역  청소년    611     384
# 4   5  2023-01-01  1호선  150  서울역  우대권   3454    1867

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
alldata_group=alldata.groupby('승객유형').sum(numeric_only=True)
alldata_group.sort_values(by='')
# Out:
#                   연번        역번호        승차인원     환승유입인원
# 승객유형
# 경로       10401606002   26807121    37415256   18971727
# 공통        1370528013    3333455           0          3
# 국가유공자    10394145577   26792455      396494     208687
# 다자녀부모         567222       2734           0          0
# 생활보호자       22413427      43197          27          5
# 어린이      40712251256  160372390     7723724    3315407
# 영어 어린이   12224133564   31680980      124732      58242
# 영어 일반    29453645098  100725891     1750261     859035
# 외국인 경로    9330576681   23281805      108397      40471
# 우대권      30345566725  133596144   215895580  108760176
# 일반       40746800637  160403265  1225655267  647980630
# 일어 어린이    5195785823    9840973       30550      14151
# 일어 일반    19136439086   55458254      798189     445791
# 장애인      10401622594   26807121     6514230    3187137
# 중고생      30071898815  112661322      173467      87068
# 중국어 어린이   6654604254   14995749       52063      24932
# ...

# %% [markdown]
# ---
# 해당 데이터는 승차인원 정보만 포함하므로 폐기

# %%
data1=pd.read_csv('./data/서울교통공사_1_8호선 역별 일별 시간대별 승객유형별 승하차인원_20231231.csv', encoding='euc-kr')
data1.head()
# Out:
#    연번        수송일자  호선명  역번호   역명 승하차구분 승객유형  06시간대이전  06-07시간대  07-08시간대  ...  \
# 0   1  2023-07-01    1  150  서울역    승차   일반      192       192       409  ...
# 1   2  2023-07-01    1  150  서울역    승차  어린이        0         1         3  ...
# 2   3  2023-07-01    1  150  서울역    승차  중고생        0         0         0  ...
# 3   4  2023-07-01    1  150  서울역    승차  청소년        0         3        12  ...
# 4   5  2023-07-01    1  150  서울역    승차  우대권       88       105       212  ...
#
#    15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  21-22시간대  \
# 0      2989      3514      3409      2686      2347      1872      2209
# 1        33        32        30        30        30        16        11
# 2         1         1         0         0         0         0         0
# 3        47        52        54        46        47        47        54
# 4       580       608       560       381       265       277       197
#
#    22-23시간대  23-24시간대  24시간대이후
# 0      1885       691        7
# ...

# %%
data2=pd.read_csv('./data/서울교통공사_1_8호선 역별 일별 시간대별 승객유형별 승하차인원_20240630.csv', encoding='euc-kr')

# %%
data=pd.concat([data1, data2])
data.head()
# Out:
#    연번        수송일자  호선명  역번호   역명 승하차구분 승객유형  06시간대이전  06-07시간대  07-08시간대  ...  \
# 0   1  2023-07-01    1  150  서울역    승차   일반      192       192       409  ...
# 1   2  2023-07-01    1  150  서울역    승차  어린이        0         1         3  ...
# 2   3  2023-07-01    1  150  서울역    승차  중고생        0         0         0  ...
# 3   4  2023-07-01    1  150  서울역    승차  청소년        0         3        12  ...
# 4   5  2023-07-01    1  150  서울역    승차  우대권       88       105       212  ...
#
#    15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  21-22시간대  \
# 0      2989      3514      3409      2686      2347      1872      2209
# 1        33        32        30        30        30        16        11
# 2         1         1         0         0         0         0         0
# 3        47        52        54        46        47        47        54
# 4       580       608       560       381       265       277       197
#
#    22-23시간대  23-24시간대  24시간대이후
# 0      1885       691        7
# ...

# %%
data.drop(
    ['연번', '호선명', '역번호'],
    axis=1,
    inplace=True
)

# %%
data_group = data.groupby('역명').sum(numeric_only=True)
data_group.head()
# Out:
#          06시간대이전  06-07시간대  07-08시간대  08-09시간대  09-10시간대  10-11시간대  11-12시간대  \
# 역명
# 가락시장      118161    317236    712584   1219027    710727    583012    583937
# 가산디지털단지   164212    481589   1944806   4878702   2776801    955987    709965
# 강남        244383    874236   2283295   4331563   4352315   2484642   2129129
# 강남구청       42570    249695    507144   1343332   1315333    615944    431024
# 강동        151200    374460    987663   1399607    765883    563145    523693
#
#          12-13시간대  13-14시간대  14-15시간대  15-16시간대  16-17시간대  17-18시간대  18-19시간대  \
# 역명
# 가락시장       601817    621828    641126    702986    769696    957416   1232037
# 가산디지털단지    768704    844480    862722    979514   1268464   2880760   4010955
# 강남        2292201   2665586   2647273   2893995   3324326   4626993   5896899
# 강남구청       426392    480252    485331    529997    603281    843307   1292964
# 강동         552501    596875    577700    632507    731062    949691   1204850
#
# ...
